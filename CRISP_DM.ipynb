# %% [markdown]
# ## Fraud Detection ML Pipeline (CRISP-DM)
#
# **Goal:** Build an end-to-end machine learning pipeline to predict `orders.is_fraud` from `data/shop.db`, with optional **`joblib`** serialization for batch scoring (not a production deployment guide).
#
# **Methodology constraint:** Follow Chapters 1-16 of the course textbook.
#
# **Hard constraint (leakage control):** Drop `risk_score` immediately after building the wide order-level dataset, before any EDA, cleaning, splitting, or modeling.
#
# **Supabase / production parity:** Set environment variable `USE_WAREHOUSE=1` and `DATABASE_URL` (or `DB_URL`) to load the denormalized table `warehouse_order_features` with the same grain as [`ml/pipeline.py`](ml/pipeline.py) / `ml.train` (one row per shipment). Otherwise the notebook uses local SQLite `data/shop.db` as before.

# %%
# Core imports used throughout the notebook
import os
import sqlite3
import time

import numpy as np
import pandas as pd

from dotenv import load_dotenv

import matplotlib.pyplot as plt
import seaborn as sns

# Modeling imports (we will use these later in the CRISP-DM Modeling phase)
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.impute import SimpleImputer

# Reproducibility (textbook frequently uses random_state=27)
SEED = 27
np.random.seed(SEED)

load_dotenv()
load_dotenv(os.path.join(os.getcwd(), "ml-deploy", ".env.local"), override=False)

# File paths
PROJECT_ROOT = os.getcwd()
DB_PATH = os.path.join(PROJECT_ROOT, "data", "shop.db")

# Target definition
TARGET_COL = "is_fraud"

# USE_WAREHOUSE=1 + DATABASE_URL (or DB_URL) → same feature table as ml/train.py
USE_WAREHOUSE = str(os.environ.get("USE_WAREHOUSE", "")).lower() in ("1", "true", "yes")

# Basic environment display settings (so tables are readable)
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)

conn = None
if USE_WAREHOUSE:
    if not (os.environ.get("DATABASE_URL") or os.environ.get("DB_URL")):
        raise RuntimeError("USE_WAREHOUSE=1 requires DATABASE_URL or DB_URL in the environment.")
    print("USE_WAREHOUSE=1: SQLite introspection cells will be skipped; wide data loads from Postgres.")
else:
    assert os.path.exists(DB_PATH), f"Database not found at: {DB_PATH}"
    conn = sqlite3.connect(DB_PATH)
    print("DB_PATH:", DB_PATH)
# Out:
# DB_PATH: c:\Users\danie\Documents\455agin\data\shop.db

# %% [markdown]
# ## 1) Business Understanding (CRISP-DM)
#
# Fraud detection problems are typically **class-imbalanced**. Because of this, we will focus on **precision/recall behavior** and summary metrics like **F1** and **Precision–Recall AUC** instead of accuracy.
#
# In plain English:
# - **False negatives** (missed fraud) are usually expensive.
# - **False positives** (flagging legit orders) create friction and manual review cost.
#
# We’ll quantify this tradeoff later using a confusion matrix and PR-focused metrics.

# %% [markdown]
# ## 2) Data Understanding (CRISP-DM)
#
# In this section we will:
# - Inspect the SQLite schema (tables + columns)
# - Build a **wide** order-level dataset (1 row = 1 order)
# - Validate the target `is_fraud` and check class imbalance

# %%
# Connect to the database and list tables so we know what we can join
if conn is None:
    print("Skipped: not using SQLite (USE_WAREHOUSE mode).")
else:
    tables = pd.read_sql_query(
        """
        SELECT name
        FROM sqlite_master
        WHERE type='table'
        ORDER BY name;
        """,
        conn,
    )
    print("Tables in shop.db:")
    print(tables.to_string(index=False))
# Out:
# Tables in shop.db:
#            name
#       customers
#     order_items
#          orders
# product_reviews
#        products
#       shipments
# sqlite_sequence

# %%
# Helper: show columns for a given table (SQLite schema introspection)
def describe_table(table_name: str) -> pd.DataFrame:
    """Return SQLite column metadata for a table."""
    return pd.read_sql_query(f"PRAGMA table_info({table_name});", conn)

if conn is None:
    print("Skipped: describe_table / orders schema (USE_WAREHOUSE mode).")
else:
    orders_schema = describe_table("orders")
    print("orders schema:")
    print(orders_schema.to_string(index=False))
# Out:
# orders schema:
#  cid           name    type  notnull dflt_value  pk
#    0       order_id INTEGER        0        NaN   1
#    1    customer_id INTEGER        1        NaN   0
#    2 order_datetime    TEXT        1        NaN   0
#    3    billing_zip    TEXT        0        NaN   0
#    4   shipping_zip    TEXT        0        NaN   0
#    5 shipping_state    TEXT        0        NaN   0
#    6 payment_method    TEXT        1        NaN   0
#    7    device_type    TEXT        1        NaN   0
#    8     ip_country    TEXT        1        NaN   0
#    9     promo_used INTEGER        1          0   0
#   10     promo_code    TEXT        0        NaN   0
#   11 order_subtotal    REAL        1        NaN   0
#   12   shipping_fee    REAL        1        NaN   0
#   13     tax_amount    REAL        1        NaN   0
#   14    order_total    REAL        1        NaN   0
#   15     risk_score    REAL        1        NaN   0
#   16       is_fraud INTEGER        1          0   0

# %%
# Inspect the schemas of the other join-candidate tables so we can design a safe 1-row-per-order JOIN
if conn is None:
    print("Skipped: multi-table schema introspection (USE_WAREHOUSE mode).")
else:
    for t in ["customers", "order_items", "shipments", "products", "product_reviews"]:
        print("\n" + "=" * 80)
        print(t)
        display(describe_table(t))
# Out:
# ================================================================================
# customers
#     cid              name     type  notnull dflt_value  pk
# 0     0       customer_id  INTEGER        0        NaN   1
# 1     1         full_name     TEXT        1        NaN   0
# 2     2             email     TEXT        1        NaN   0
# 3     3            gender     TEXT        1        NaN   0
# 4     4         birthdate     TEXT        1        NaN   0
# 5     5        created_at     TEXT        1        NaN   0
# 6     6              city     TEXT        0        NaN   0
# 7     7             state     TEXT        0        NaN   0
# 8     8          zip_code     TEXT        0        NaN   0
# 9     9  customer_segment     TEXT        0        NaN   0
# 10   10      loyalty_tier     TEXT        0        NaN   0
# 11   11         is_active  INTEGER        1          1   0
# ================================================================================
# order_items
#    cid           name     type  notnull dflt_value  pk
# 0    0  order_item_id  INTEGER        0       None   1
# 1    1       order_id  INTEGER        1       None   0
# 2    2     product_id  INTEGER        1       None   0
# 3    3       quantity  INTEGER        1       None   0
# 4    4     unit_price     REAL        1       None   0
# 5    5     line_total     REAL        1       None   0
# ================================================================================
# shipments
#    cid             name     type  notnull dflt_value  pk
# 0    0      shipment_id  INTEGER        0        NaN   1
# 1    1         order_id  INTEGER        1        NaN   0
# 2    2    ship_datetime     TEXT        1        NaN   0
# 3    3          carrier     TEXT        1        NaN   0
# 4    4  shipping_method     TEXT        1        NaN   0
# 5    5    distance_band     TEXT        1        NaN   0
# 6    6    promised_days  INTEGER        1        NaN   0
# 7    7      actual_days  INTEGER        1        NaN   0
# 8    8    late_delivery  INTEGER        1          0   0
# ================================================================================
# products
#    cid          name     type  notnull dflt_value  pk
# 0    0    product_id  INTEGER        0        NaN   1
# 1    1           sku     TEXT        1        NaN   0
# 2    2  product_name     TEXT        1        NaN   0
# 3    3      category     TEXT        1        NaN   0
# 4    4         price     REAL        1        NaN   0
# 5    5          cost     REAL        1        NaN   0
# 6    6     is_active  INTEGER        1          1   0
# ================================================================================
# product_reviews
#    cid             name     type  notnull dflt_value  pk
# 0    0        review_id  INTEGER        0       None   1
# 1    1      customer_id  INTEGER        1       None   0
# 2    2       product_id  INTEGER        1       None   0
# 3    3           rating  INTEGER        1       None   0
# 4    4  review_datetime     TEXT        1       None   0
# 5    5      review_text     TEXT        0       None   0

# %% [markdown]
# ### Build a denormalized (wide) order-level dataset
#
# **Goal:** One row per `order_id` (SQLite path) or per `shipment_id` in `warehouse_order_features` (Postgres / `USE_WAREHOUSE=1`).
#
# Important design rule:
# - `order_items` is one-to-many per order, so we **aggregate it** to order-level features (counts, totals, distinct categories, etc.).
# - `shipments` is one-to-one here (1 shipment per order), so we can join it directly.
# - We will JOIN `customers` directly (dimension table).
#
# **Leakage control:** we will drop `risk_score` immediately after loading the wide DataFrame.

# %%
# Denormalize: orders (grain) + customers + shipments + aggregated order_items (+ product attributes)
# Every row in df_wide represents exactly one order (SQLite) or one shipment (Postgres warehouse).
if USE_WAREHOUSE:
    import psycopg2
    from ml.pipeline import FEATURE_TABLE

    _url = os.environ.get("DATABASE_URL") or os.environ.get("DB_URL")
    _pg = psycopg2.connect(_url)
    df_wide = pd.read_sql_query(f'SELECT * FROM "{FEATURE_TABLE}"', _pg)
    _pg.close()
    print("Loaded warehouse table:", FEATURE_TABLE, "shape:", df_wide.shape)
else:
    wide_query = """
WITH
order_item_rollup AS (
    SELECT
        oi.order_id,
        COUNT(*) AS n_line_items,
        SUM(oi.quantity) AS n_units,
        SUM(oi.line_total) AS items_revenue,
        AVG(oi.unit_price) AS avg_unit_price,
        MAX(oi.unit_price) AS max_unit_price,
        MIN(oi.unit_price) AS min_unit_price,
        COUNT(DISTINCT oi.product_id) AS n_distinct_products,
        COUNT(DISTINCT p.category) AS n_distinct_categories,
        -- A few simple composition signals
        SUM(CASE WHEN p.is_active = 1 THEN oi.quantity ELSE 0 END) AS units_active_products,
        SUM(CASE WHEN p.is_active = 0 THEN oi.quantity ELSE 0 END) AS units_inactive_products,
        SUM(oi.quantity * p.cost) AS est_cogs
    FROM order_items oi
    LEFT JOIN products p
      ON oi.product_id = p.product_id
    GROUP BY oi.order_id
),
customer_rollup AS (
    -- customers is already 1 row per customer_id; we keep it as-is but isolate it for readability
    SELECT
        customer_id,
        gender,
        birthdate,
        created_at AS customer_created_at,
        city,
        state,
        zip_code,
        customer_segment,
        loyalty_tier,
        is_active AS customer_is_active
    FROM customers
)
SELECT
    o.order_id,
    o.customer_id,
    o.order_datetime,
    o.billing_zip,
    o.shipping_zip,
    o.shipping_state,
    o.payment_method,
    o.device_type,
    o.ip_country,
    o.promo_used,
    o.promo_code,
    o.order_subtotal,
    o.shipping_fee,
    o.tax_amount,
    o.order_total,
    o.risk_score,
    o.is_fraud,

    c.gender,
    c.birthdate,
    c.customer_created_at,
    c.city AS customer_city,
    c.state AS customer_state,
    c.zip_code AS customer_zip,
    c.customer_segment,
    c.loyalty_tier,
    c.customer_is_active,

    s.ship_datetime,
    s.carrier,
    s.shipping_method,
    s.distance_band,
    s.promised_days,
    s.actual_days,
    s.late_delivery,

    r.n_line_items,
    r.n_units,
    r.items_revenue,
    r.avg_unit_price,
    r.max_unit_price,
    r.min_unit_price,
    r.n_distinct_products,
    r.n_distinct_categories,
    r.units_active_products,
    r.units_inactive_products,
    r.est_cogs

FROM orders o
LEFT JOIN customer_rollup c
  ON o.customer_id = c.customer_id
LEFT JOIN shipments s
  ON o.order_id = s.order_id
LEFT JOIN order_item_rollup r
  ON o.order_id = r.order_id
;
"""

    df_wide = pd.read_sql_query(wide_query, conn)

print("Wide dataset shape:", df_wide.shape)
print("Unique orders:", df_wide["order_id"].nunique())

# Hard constraint: drop risk_score immediately to avoid leakage
if "risk_score" in df_wide.columns:
    df_wide = df_wide.drop(columns=["risk_score"])

# Sanity checks
if "shipment_id" in df_wide.columns:
    assert df_wide["shipment_id"].nunique() == len(df_wide), "Wide table is not 1 row per shipment_id."
else:
    assert df_wide.shape[0] == df_wide["order_id"].nunique(), "Wide table is not 1 row per order."
assert TARGET_COL in df_wide.columns, f"Target column missing: {TARGET_COL}"

df_wide.head()
# Out:
# Wide dataset shape: (5000, 44)
# Unique orders: 5000
#    order_id  customer_id       order_datetime billing_zip shipping_zip  \
# 0         1            1  2025-11-29 00:51:07       28289        28289
# 1         2            1  2025-09-01 10:25:59       28289        13888
# 2         3            1  2025-12-15 07:24:41       28289        28289
# 3         4            1  2025-11-06 18:21:19       28289        28289
# 4         5            1  2025-11-30 05:34:15       28289        28289
#
#   shipping_state payment_method device_type ip_country  promo_used promo_code  \
# 0             CO           card      mobile         US           0        NaN
# 1             NY           card     desktop         US           1     SAVE10
# 2             CO           card      mobile         US           0        NaN
# 3             CO           bank      mobile         US           1    WELCOME
# 4             CO           card      mobile         CA           0        NaN
#
#    order_subtotal  shipping_fee  tax_amount  order_total  is_fraud  gender  \
# 0          662.95         15.44       46.30       724.69         0  Female
# 1          862.92         14.74       66.61       944.27         0  Female
# 2          796.09         14.04       40.72       850.85         1  Female
# 3          137.60          6.99       11.88       156.47         0  Female
# 4           17.07          6.99        1.40        25.46         0  Female
#
#     birthdate  customer_created_at customer_city customer_state customer_zip  \
# 0  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 1  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 2  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 3  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 4  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
#
#   customer_segment loyalty_tier  customer_is_active        ship_datetime  \
# 0         standard       silver                   1  2025-11-29 09:51:07
# 1         standard       silver                   1  2025-09-02 08:25:59
# 2         standard       silver                   1  2025-12-16 13:24:41
# 3         standard       silver                   1  2025-11-07 21:21:19
# 4         standard       silver                   1  2025-12-01 14:34:15
#
#   carrier shipping_method distance_band  promised_days  actual_days  \
# 0     UPS       expedited      regional              3            5
# 1   FedEx       expedited         local              2            3
# 2   FedEx       expedited      national              4            8
# 3     UPS        standard      regional              6            6
# 4    USPS        standard      regional              6            7
#
#    late_delivery  n_line_items  n_units  items_revenue  avg_unit_price  \
# 0              1             5        9         662.95          69.242
# 1              1             5        7         862.92         133.300
# 2              1             3        5         796.09         140.850
# 3              0             1        1         137.60         137.600
# 4              1             1        1          17.07          17.070
#
#    max_unit_price  min_unit_price  n_distinct_products  n_distinct_categories  \
# 0           99.90           23.16                    5                      4
# 1          241.51           47.27                    5                      3
# 2          230.50           49.01                    3                      2
# 3          137.60          137.60                    1                      1
# 4           17.07           17.07                    1                      1
#
#    units_active_products  units_inactive_products  est_cogs
# 0                      9                        0    407.95
# 1                      7                        0    502.81
# 2                      5                        0    498.39
# 3                      1                        0     82.66
# 4                      1                        0      8.38

# %% [markdown]
# ## 3) Data Preparation (CRISP-DM)
#
# We will implement the textbook’s “Gold Standard” cleaning patterns (Ch. 7):
# - Basic structural wrangling (drop mostly-missing / mostly-unique / constant columns)
# - Missing-data strategy (drop biggest offenders, then decide drop vs impute)
# - Outlier handling (skew-aware: Tukey IQR vs Empirical Rule)
#
# Important note for leakage safety:
# - We will freeze a test set later (Ch. 15 discipline). Any learning-based imputation will be fit on training data only.

# %%
# --- Chapter 7-inspired basic wrangling helpers ---

def basic_wrangling(
    df: pd.DataFrame,
    features: list[str] | None = None,
    missing_threshold: float = 0.95,
    unique_threshold: float = 0.95,
    messages: bool = True,
) -> pd.DataFrame:
    """Drop (1) mostly-missing, (2) mostly-unique identifier-like, and (3) constant columns.

    This follows the Chapter 7 'basic_wrangling' first-step pattern.
    """
    df = df.copy()

    if not features:
        features = df.columns.tolist()

    rows = df.shape[0]
    for feat in features:
        if feat not in df.columns:
            if messages:
                print(f'Skipping "{feat}": Column not found')
            continue

        missing = int(df[feat].isna().sum())
        unique = int(df[feat].nunique(dropna=True))

        # 1) Too missing
        if rows > 0 and (missing / rows) >= missing_threshold:
            if messages:
                print(f"Dropping {feat}: {missing} missing out of {rows} ({missing/rows:.2%})")
            df = df.drop(columns=[feat])
            continue

        # 2) Identifier-like (too many unique values) for common dtypes
        if rows > 0 and (unique / rows) >= unique_threshold:
            if df[feat].dtype.name in ["int64", "object", "string"]:
                if messages:
                    print(f"Dropping {feat}: {unique} unique out of {rows} ({unique/rows:.2%})")
                df = df.drop(columns=[feat])
                continue

        # 3) Constant columns
        if unique == 1:
            if messages:
                val = df[feat].dropna().unique()
                val = val[0] if len(val) else None
                print(f"Dropping {feat}: constant value ({val})")
            df = df.drop(columns=[feat])

    return df


def clean_outlier(
    df: pd.DataFrame,
    features: list[str] | None = None,
    method: str = "replace",
    messages: bool = True,
    skew_threshold: float = 1.0,
) -> pd.DataFrame:
    """Skew-aware outlier handling (Chapter 7 pattern).

    - If |skew| > skew_threshold, use Tukey IQR fences.
    - Else, use Empirical Rule (mean ± 3 std).

    method:
    - 'remove': drop rows with outliers
    - 'replace': cap to min/max fence
    - 'null': set outliers to NaN

    Note: We skip binary 0/1 columns.
    """
    df = df.copy()

    if not features:
        features = df.columns.tolist()

    for feat in features:
        if feat not in df.columns:
            continue
        if not pd.api.types.is_numeric_dtype(df[feat]):
            continue

        # Skip constant columns
        if df[feat].nunique(dropna=True) <= 1:
            continue

        # Skip binary dummy columns
        vals = set(pd.Series(df[feat].dropna().unique()).tolist())
        if vals.issubset({0, 1}):
            continue

        skew = float(df[feat].skew())

        if abs(skew) > skew_threshold:
            q1 = float(df[feat].quantile(0.25))
            q3 = float(df[feat].quantile(0.75))
            iqr = q3 - q1
            lower = q1 - 1.5 * iqr
            upper = q3 + 1.5 * iqr
            rule = "Tukey_IQR"
        else:
            mean = float(df[feat].mean())
            std = float(df[feat].std())
            lower = mean - 3.0 * std
            upper = mean + 3.0 * std
            rule = "Empirical_3sigma"

        below = int((df[feat] < lower).sum())
        above = int((df[feat] > upper).sum())
        if (below + above) == 0:
            continue

        if messages:
            print(f"{feat}: {rule} lower={lower:.4f} upper={upper:.4f} | below={below} above={above}")

        if method == "remove":
            df = df[(df[feat] >= lower) & (df[feat] <= upper)]
        elif method == "replace":
            if pd.api.types.is_integer_dtype(df[feat]):
                df[feat] = df[feat].astype(float)
            df.loc[df[feat] < lower, feat] = lower
            df.loc[df[feat] > upper, feat] = upper
        elif method == "null":
            df.loc[df[feat] < lower, feat] = np.nan
            df.loc[df[feat] > upper, feat] = np.nan
        else:
            raise ValueError("method must be one of: 'remove', 'replace', 'null'")

    return df

# %%
# Apply basic wrangling and outlier handling to the wide table
# (We do not split train/test until Chapter 15; at this stage we focus on structural cleaning.)

print("Starting shape:", df_wide.shape)

# Drop obvious non-features / identifiers (keep order_id separately for auditing)
ID_COLS = (
    ["shipment_id", "order_id"]
    if "shipment_id" in df_wide.columns
    else ["order_id", "customer_id"]
)

# Run structural wrangling on non-ID columns
cols_for_wrangling = [c for c in df_wide.columns if c not in ID_COLS]
df_clean = basic_wrangling(df_wide, features=cols_for_wrangling, messages=True)
print("After basic_wrangling:", df_clean.shape)

# Outlier handling on numeric features (cap by default to preserve row count)
numeric_cols = df_clean.select_dtypes(include=["number"]).columns.tolist()
# Exclude target from outlier logic
numeric_cols = [c for c in numeric_cols if c != TARGET_COL]

df_clean = clean_outlier(df_clean, features=numeric_cols, method="replace", messages=True)
print("After clean_outlier (replace/cap):", df_clean.shape)

df_clean.head()
# Out:
# Starting shape: (5000, 43)
# Dropping customer_is_active: constant value (1)
# Dropping units_inactive_products: constant value (0)
# After basic_wrangling: (5000, 41)
# customer_id: Tukey_IQR lower=-37.0000 upper=67.0000 | below=0 above=683
# order_subtotal: Tukey_IQR lower=-414.1788 upper=1128.1113 | below=0 above=85
# shipping_fee: Tukey_IQR lower=-2.0100 upper=21.9900 | below=0 above=292
# tax_amount: Tukey_IQR lower=-30.0537 upper=80.6762 | below=0 above=134
# order_total: Tukey_IQR lower=-431.0100 upper=1213.7100 | below=0 above=89
# actual_days: Empirical_3sigma lower=-0.3220 upper=12.0672 | below=0 above=2
# n_units: Empirical_3sigma lower=-2.5310 upper=10.7490 | below=0 above=11
# items_revenue: Tukey_IQR lower=-414.1788 upper=1128.1113 | below=0 above=85
# avg_unit_price: Empirical_3sigma lower=-60.5875 upper=247.0161 | below=0 above=28
# min_unit_price: Tukey_IQR lower=-42.5350 upper=106.3850 | below=0 above=544
# units_active_products: Empirical_3sigma lower=-2.5310 upper=10.7490 | below=0 above=11
# est_cogs: Tukey_IQR lower=-254.9663 upper=679.7838 | below=0 above=116
# After clean_outlier (replace/cap): (5000, 41)
#    order_id  customer_id       order_datetime billing_zip shipping_zip  \
# 0         1          1.0  2025-11-29 00:51:07       28289        28289
# 1         2          1.0  2025-09-01 10:25:59       28289        13888
# 2         3          1.0  2025-12-15 07:24:41       28289        28289
# 3         4          1.0  2025-11-06 18:21:19       28289        28289
# 4         5          1.0  2025-11-30 05:34:15       28289        28289
#
#   shipping_state payment_method device_type ip_country  promo_used promo_code  \
# 0             CO           card      mobile         US           0        NaN
# 1             NY           card     desktop         US           1     SAVE10
# 2             CO           card      mobile         US           0        NaN
# 3             CO           bank      mobile         US           1    WELCOME
# 4             CO           card      mobile         CA           0        NaN
#
#    order_subtotal  shipping_fee  tax_amount  order_total  is_fraud  gender  \
# 0          662.95         15.44       46.30       724.69         0  Female
# 1          862.92         14.74       66.61       944.27         0  Female
# 2          796.09         14.04       40.72       850.85         1  Female
# 3          137.60          6.99       11.88       156.47         0  Female
# 4           17.07          6.99        1.40        25.46         0  Female
#
#     birthdate  customer_created_at customer_city customer_state customer_zip  \
# 0  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 1  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 2  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 3  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
# 4  2005-06-08  2025-10-11 16:37:40       Clayton             CO        28289
#
#   customer_segment loyalty_tier        ship_datetime carrier shipping_method  \
# 0         standard       silver  2025-11-29 09:51:07     UPS       expedited
# 1         standard       silver  2025-09-02 08:25:59   FedEx       expedited
# 2         standard       silver  2025-12-16 13:24:41   FedEx       expedited
# 3         standard       silver  2025-11-07 21:21:19     UPS        standard
# 4         standard       silver  2025-12-01 14:34:15    USPS        standard
#
#   distance_band  promised_days  actual_days  late_delivery  n_line_items  \
# 0      regional              3          5.0              1             5
# 1         local              2          3.0              1             5
# 2      national              4          8.0              1             3
# 3      regional              6          6.0              0             1
# 4      regional              6          7.0              1             1
#
#    n_units  items_revenue  avg_unit_price  max_unit_price  min_unit_price  \
# 0      9.0         662.95          69.242           99.90          23.160
# 1      7.0         862.92         133.300          241.51          47.270
# 2      5.0         796.09         140.850          230.50          49.010
# 3      1.0         137.60         137.600          137.60         106.385
# 4      1.0          17.07          17.070           17.07          17.070
#
#    n_distinct_products  n_distinct_categories  units_active_products  est_cogs
# 0                    5                      4                    9.0    407.95
# 1                    5                      3                    7.0    502.81
# 2                    3                      2                    5.0    498.39
# 3                    1                      1                    1.0     82.66
# 4                    1                      1                    1.0      8.38

# %% [markdown]
# ### Missing values (Chapter 7 approach)
#
# Chapter 7’s pattern is:
# - Drop the biggest offenders first (rows/columns missing “too much”) to preserve usable data.
# - Then decide whether to **drop remaining missing rows** (if missingness appears biased/MAR) or **impute** (if missingness behaves like MCAR).
#
# In this project, we’ll implement the same spirit, but we’ll do it in a **leakage-safe** way:
# - We will finalize imputation **inside the modeling pipeline** later, so the imputer is fit on training folds only.
#
# For now, we’ll summarize missingness and remove only extreme cases.

# %%
# Summarize missingness and drop only columns/rows that are missing too much

def missing_summary(df: pd.DataFrame) -> pd.DataFrame:
    """Return a simple missingness table."""
    out = pd.DataFrame({
        "missing": df.isna().sum(),
        "missing_pct": df.isna().mean(),
        "dtype": df.dtypes.astype(str),
    })
    out = out.sort_values(by=["missing_pct", "missing"], ascending=False)
    return out

ms = missing_summary(df_clean)
display(ms.head(25))

# Conservative thresholds inspired by Chapter 7 drop-first logic
COL_THRESHOLD = 0.50  # drop columns missing >= 50%
ROW_THRESHOLD = 0.90  # keep rows with at least 90% non-null cells

start_shape = df_clean.shape

# Drop columns with too much missingness
cols_to_drop = ms.index[ms["missing_pct"] >= COL_THRESHOLD].tolist()
# Never drop target
cols_to_drop = [c for c in cols_to_drop if c != TARGET_COL]

df_clean2 = df_clean.drop(columns=cols_to_drop)

# Drop rows that are missing too much data
min_nonnull = int(np.ceil(ROW_THRESHOLD * df_clean2.shape[1]))
df_clean2 = df_clean2.dropna(axis=0, thresh=min_nonnull)

# Ensure target has no missing values
if df_clean2[TARGET_COL].isna().any():
    df_clean2 = df_clean2.dropna(subset=[TARGET_COL])

print("Start shape:", start_shape)
print("Dropped columns:", len(cols_to_drop))
print("End shape:", df_clean2.shape)

ms2 = missing_summary(df_clean2)
display(ms2.head(25))
# Out:
#                      missing  missing_pct    dtype
# promo_code              3739       0.7478      str
# order_id                   0       0.0000    int64
# customer_id                0       0.0000  float64
# order_datetime             0       0.0000      str
# billing_zip                0       0.0000      str
# shipping_zip               0       0.0000      str
# shipping_state             0       0.0000      str
# payment_method             0       0.0000      str
# device_type                0       0.0000      str
# ip_country                 0       0.0000      str
# promo_used                 0       0.0000    int64
# order_subtotal             0       0.0000  float64
# shipping_fee               0       0.0000  float64
# tax_amount                 0       0.0000  float64
# order_total                0       0.0000  float64
# is_fraud                   0       0.0000    int64
# gender                     0       0.0000      str
# birthdate                  0       0.0000      str
# customer_created_at        0       0.0000      str
# customer_city              0       0.0000      str
# customer_state             0       0.0000      str
# customer_zip               0       0.0000      str
# customer_segment           0       0.0000      str
# loyalty_tier               0       0.0000      str
# ship_datetime              0       0.0000      str
# Start shape: (5000, 41)
# Dropped columns: 1
# End shape: (5000, 40)
#                      missing  missing_pct    dtype
# order_id                   0          0.0    int64
# customer_id                0          0.0  float64
# order_datetime             0          0.0      str
# billing_zip                0          0.0      str
# shipping_zip               0          0.0      str
# shipping_state             0          0.0      str
# payment_method             0          0.0      str
# device_type                0          0.0      str
# ip_country                 0          0.0      str
# promo_used                 0          0.0    int64
# order_subtotal             0          0.0  float64
# shipping_fee               0          0.0  float64
# tax_amount                 0          0.0  float64
# order_total                0          0.0  float64
# is_fraud                   0          0.0    int64
# gender                     0          0.0      str
# birthdate                  0          0.0      str
# customer_created_at        0          0.0      str
# customer_city              0          0.0      str
# customer_state             0          0.0      str
# customer_zip               0          0.0      str
# customer_segment           0          0.0      str
# loyalty_tier               0          0.0      str
# ship_datetime              0          0.0      str
# carrier                    0          0.0      str

# %% [markdown]
# ## Modeling Preprocessing Pipeline (leakage-safe)
#
# To ensure we do not leak information across folds (Chapter 15 discipline), we will:
# - Keep imputation, encoding, and scaling **inside** an `sklearn` `Pipeline`.
# - Use a `ColumnTransformer` to apply the right transformations by dtype.
#
# This is the “one pipeline reused everywhere” idea used throughout the classification + ensemble chapters.

# %%
# Define X/y for modeling
# We keep order_id as an audit key, but we will exclude it from modeling features.


def make_column_preprocessor(X_df: pd.DataFrame) -> tuple[ColumnTransformer, list[str], list[str]]:
    """Build a ColumnTransformer from the feature columns of X_df."""
    cat_cols = X_df.select_dtypes(include=["object"]).columns.tolist()
    num_cols = X_df.select_dtypes(include=["number"]).columns.tolist()
    numeric_pipe = Pipeline(steps=[
        ("impute", SimpleImputer(strategy="median")),
        ("scale", StandardScaler()),
    ])
    categorical_pipe = Pipeline(steps=[
        ("impute", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown="ignore")),
    ])
    prep = ColumnTransformer(
        transformers=[
            ("num", numeric_pipe, num_cols),
            ("cat", categorical_pipe, cat_cols),
        ],
        remainder="drop",
    )
    return prep, cat_cols, num_cols


df_model = df_clean2.copy()

y = df_model[TARGET_COL].astype(int)

X = df_model.drop(columns=[TARGET_COL])
X = X.drop(columns=[c for c in ["order_id", "shipment_id"] if c in X.columns])

preprocessor, cat_cols, num_cols = make_column_preprocessor(X)

print("n_rows:", X.shape[0])
print("n_features:", X.shape[1])
print("n_numeric:", len(num_cols), "n_categorical:", len(cat_cols))

preprocessor
# Out:
# n_rows: 5000
# n_features: 38
# n_numeric: 19 n_categorical: 19
# C:\Users\danie\AppData\Local\Temp\ipykernel_20684\2574022909.py:7: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = X_df.select_dtypes(include=["object"]).columns.tolist()
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scale', StandardScaler())]),
#                                  ['customer_id', 'promo_used', 'order_subtotal',
#                                   'shipping_fee', 'tax_amount', 'order_total',
#                                   'promised_days', 'actual_days',
#                                   'late_delivery', 'n_line_items', 'n_units',
#                                   'items_revenue', 'avg_unit_price',
#                                   'max_unit_price', 'min_unit_pric...
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['order_datetime', 'billing_zip',
#                                   'shipping_zip', 'shipping_state',
#                                   'payment_method', 'device_type', 'ip_country',
#                                   'gender', 'birthdate', 'customer_created_at',
#                                   'customer_city', 'customer_state',
#                                   'customer_zip', 'customer_segment',
#                                   'loyalty_tier', 'ship_datetime', 'carrier',
#                                   'shipping_method', 'distance_band'])])

# %% [markdown]
# ## 4) Exploratory Data Analysis (EDA)
#
# We’ll focus on identifying relationships with `is_fraud` and understanding class imbalance.
#
# Notes:
# - For categorical features we’ll look at **fraud rate by category**.
# - For numeric features we’ll look at distributions and simple correlations.

# %%
# EDA: fraud rate, plus top numeric correlations (quick screen)

eda_df = df_model[[TARGET_COL] + [c for c in df_model.columns if c != TARGET_COL]].copy()

# 1) Target distribution (again, after cleaning)
counts = eda_df[TARGET_COL].value_counts().sort_index()
fraud_rate = counts.get(1, 0) / counts.sum()
print("n_orders:", int(counts.sum()))
print("fraud_rate:", round(float(fraud_rate), 4))
print(counts.to_string())

# 2) Numeric correlations (only numeric columns)
num_cols_eda = eda_df.select_dtypes(include=["number"]).columns.tolist()
if TARGET_COL in num_cols_eda:
    corr = eda_df[num_cols_eda].corr(numeric_only=True)
    target_corr = corr[TARGET_COL].drop(TARGET_COL).sort_values(key=lambda s: s.abs(), ascending=False)
    display(target_corr.head(15).to_frame("corr_with_is_fraud"))

    plt.figure(figsize=(6, 8))
    target_corr.head(15).sort_values().plot(kind="barh")
    plt.title("Top numeric correlations with is_fraud (screening)")
    plt.xlabel("correlation")
    plt.tight_layout()
    plt.show()
# Out:
# n_orders: 5000
# fraud_rate: 0.0636
# is_fraud
# 0    4682
# 1     318
#                        corr_with_is_fraud
# actual_days                      0.320027
# late_delivery                    0.212898
# items_revenue                    0.203317
# order_subtotal                   0.203317
# order_total                      0.203092
# est_cogs                         0.199824
# tax_amount                       0.193727
# n_units                          0.141359
# units_active_products            0.141359
# max_unit_price                   0.132270
# n_line_items                     0.122913
# n_distinct_products              0.122913
# n_distinct_categories            0.111561
# avg_unit_price                   0.105272
# order_id                        -0.090121

# %%
# EDA: fraud rate by category (top categories only to keep it readable)

def fraud_rate_by_category(df: pd.DataFrame, col: str, min_count: int = 30) -> pd.DataFrame:
    """Compute fraud rate by category, filtering to categories with enough rows."""
    tmp = df[[col, TARGET_COL]].copy()
    tmp[col] = tmp[col].astype("object").fillna("(missing)")

    grp = tmp.groupby(col)[TARGET_COL].agg(["count", "mean"]).rename(columns={"mean": "fraud_rate"})
    grp = grp.sort_values(by="count", ascending=False)
    grp = grp[grp["count"] >= min_count].sort_values(by="fraud_rate", ascending=False)
    return grp

cat_candidates = [
    c for c in df_model.columns
    if c in ["payment_method", "device_type", "ip_country", "shipping_state", "carrier", "shipping_method", "distance_band", "customer_segment", "loyalty_tier"]
    and c in df_model.columns
]

for c in cat_candidates:
    print("\n" + "=" * 80)
    print("Fraud rate by:", c)
    tbl = fraud_rate_by_category(df_model, c, min_count=30)
    display(tbl.head(15))

    if tbl.shape[0] > 0:
        plt.figure(figsize=(7, 4))
        tbl.head(10).sort_values("fraud_rate").plot(y="fraud_rate", kind="barh", legend=False)
        plt.title(f"Top categories by fraud rate: {c} (min_count=30)")
        plt.xlabel("fraud_rate")
        plt.tight_layout()
        plt.show()
# Out:
# ================================================================================
# Fraud rate by: shipping_state
#                 count  fraud_rate
# shipping_state
# CO               1702    0.091657
# TX                350    0.082857
# OR                106    0.075472
# VA                 47    0.063830
# WA                164    0.060976
# CA                100    0.060000
# FL                244    0.057377
# GA                112    0.053571
# OH                390    0.048718
# PA                147    0.047619
# NC                338    0.041420
# MI                367    0.040872
# UT                148    0.040541
# NY                149    0.040268
# IL                232    0.038793
# ================================================================================
# Fraud rate by: payment_method
#                 count  fraud_rate
# payment_method
# crypto             97    0.103093
# card             3128    0.067455
# bank              725    0.059310
# paypal           1050    0.051429
# ================================================================================
# Fraud rate by: device_type
#              count  fraud_rate
# device_type
# mobile        2734    0.068032
# tablet         364    0.065934
# desktop       1902    0.056782
# ================================================================================
# Fraud rate by: ip_country
#             count  fraud_rate
# ip_country
# IN             95    0.094737
# GB            104    0.086538
# BR             41    0.073171
# CA            218    0.068807
# NG             46    0.065217
# US           4496    0.062055
# ================================================================================
# Fraud rate by: customer_segment
#                   count  fraud_rate
# customer_segment
# standard           2890    0.067128
# budget             1764    0.062358
# premium             346    0.040462
# ================================================================================
# Fraud rate by: loyalty_tier
#               count  fraud_rate
# loyalty_tier
# silver         2220    0.073423
# none           1930    0.062176
# gold            850    0.041176
# ================================================================================
# Fraud rate by: carrier
#          count  fraud_rate
# carrier
# USPS       997    0.067202
# FedEx     1705    0.063930
# UPS       2298    0.061793
# ================================================================================
# Fraud rate by: shipping_method
#                  count  fraud_rate
# shipping_method
# overnight          303    0.079208
# standard          3618    0.063847
# expedited         1079    0.058387
# ================================================================================
# Fraud rate by: distance_band
#                count  fraud_rate
# distance_band
# national         990    0.072727
# local           1716    0.068765
# regional        2294    0.055798

# %% [markdown]
# ## 5) Modeling (Baselines + Ensembles)
#
# Textbook discipline (Ch. 15):
# - Freeze a **single** stratified test set once.
# - Use cross-validation on the training set for fair comparison.
#
# We will compare the **10 total models** from the Chapter 14 workflow:
# - Baselines: Logistic Regression, Shallow Decision Tree, k-NN, Naive Bayes
# - Ensembles: Bagging, Random Forest, AdaBoost, Gradient Boosting (GBDT), XGBoost (if available), Stacking
#
# Primary metric focus for fraud:
# - **F1** (positive class) and **Average Precision** (PR AUC)

# %%
# Freeze a stratified test split once (Chapter 15 discipline)
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=SEED,
    stratify=y,
)

X_tr_pfi, X_val_pfi, y_tr_pfi, y_val_pfi = train_test_split(
    X_train,
    y_train,
    test_size=0.20,
    random_state=SEED,
    stratify=y_train,
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print("PFI sub-train:", X_tr_pfi.shape, "| PFI validation:", X_val_pfi.shape)
print("Train fraud rate:", round(float(y_train.mean()), 4))
print("Test fraud rate:", round(float(y_test.mean()), 4))

# Shared CV object for all comparisons
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
# Out:
# Train shape: (4000, 38)
# Test shape: (1000, 38)
# PFI sub-train: (3200, 38) | PFI validation: (800, 38)
# Train fraud rate: 0.0635
# Test fraud rate: 0.064

# %%
# Build the 10-model comparison set (Chapter 14 structure)
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.metrics import make_scorer, f1_score
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline

# If you run this cell without running the top-of-notebook imports,
# we still want these symbols available.
import numpy as np

# XGBoost is required for this workflow (textbook Chapter 14).
# On macOS, XGBoost may also require the OpenMP runtime (libomp).
# If we hit the common libomp error, we'll print the fix instead of silently skipping.
import sys
import subprocess

try:
    from xgboost import XGBClassifier
    HAS_XGBOOST = True
except Exception as e:
    print("XGBoost import failed; attempting to install into this notebook kernel...")
    print("Original error:", repr(e))

    subprocess.check_call([sys.executable, "-m", "pip", "install", "xgboost"])

    try:
        from xgboost import XGBClassifier
        HAS_XGBOOST = True
    except Exception as e2:
        msg = repr(e2)
        print("\nXGBoost installed but still cannot be imported.")
        print("Error:", msg)

        # Most common macOS issue: missing libomp
        if "libomp" in msg or "libomp.dylib" in msg:
            print("\nFix (macOS): install OpenMP runtime, then restart your notebook kernel:")
            print("  brew install libomp")
            print("After installing, restart the kernel and rerun the notebook.")

        # Hard fail (we do not skip XGBoost)
        raise

# Scoring: focus on positive-class F1 and PR AUC (Average Precision)
scoring = {
    "f1_pos": make_scorer(f1_score, pos_label=1),
    "avg_precision": "average_precision",
    "roc_auc": "roc_auc",
}

# Helper to densify for GaussianNB (because OneHot can produce sparse matrices)
to_dense = FunctionTransformer(
    lambda X: X.toarray() if hasattr(X, "toarray") else np.asarray(X),
    accept_sparse=True,
)

def build_models(preprocessor):
    models = []

    # --- Baselines (Ch. 14 baseline section) ---
    models.append((
        "LogisticRegression",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", LogisticRegression(max_iter=2000, random_state=SEED)),
        ]),
    ))

    models.append((
        "DecisionTree_depth3",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", DecisionTreeClassifier(max_depth=3, random_state=SEED)),
        ]),
    ))

    models.append((
        "KNN_k15",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", KNeighborsClassifier(n_neighbors=15)),
        ]),
    ))

    models.append((
        "GaussianNB",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("dense", to_dense),
            ("clf", GaussianNB()),
        ]),
    ))

    # --- Ensembles (Ch. 14) ---
    base_tree_depth3 = DecisionTreeClassifier(max_depth=3, random_state=SEED)

    models.append((
        "Bagging_depth3",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", BaggingClassifier(
                estimator=base_tree_depth3,
                n_estimators=200,
                bootstrap=True,
                n_jobs=-1,
                random_state=SEED,
            )),
        ]),
    ))

    models.append((
        "RandomForest",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", RandomForestClassifier(
                n_estimators=400,
                random_state=SEED,
                n_jobs=-1,
            )),
        ]),
    ))

    # AdaBoost with decision stumps (depth=1) follows the chapter’s common pattern
    models.append((
        "AdaBoost_stumps",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", AdaBoostClassifier(
                estimator=DecisionTreeClassifier(max_depth=1, random_state=SEED),
                n_estimators=300,
                learning_rate=0.5,
                random_state=SEED,
            )),
        ]),
    ))

    models.append((
        "GradientBoosting_GBDT",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", GradientBoostingClassifier(
                n_estimators=300,
                learning_rate=0.05,
                max_depth=3,
                random_state=SEED,
            )),
        ]),
    ))

    if HAS_XGBOOST:
        models.append((
            "XGBoost",
            Pipeline(steps=[
                ("prep", preprocessor),
                ("clf", XGBClassifier(
                    objective="binary:logistic",
                    eval_metric="logloss",
                    n_estimators=500,
                    learning_rate=0.05,
                    max_depth=3,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    reg_lambda=1.0,
                    n_jobs=-1,
                    random_state=SEED,
                )),
            ]),
        ))

    # Stacking: combine a few diverse base learners with a logistic regression meta-model
    stack_estimators = [
        ("lr", LogisticRegression(max_iter=2000, random_state=SEED)),
        ("rf", RandomForestClassifier(n_estimators=300, random_state=SEED, n_jobs=-1)),
        ("knn", KNeighborsClassifier(n_neighbors=15)),
    ]

    models.append((
        "Stacking_LR_RF_KNN",
        Pipeline(steps=[
            ("prep", preprocessor),
            ("clf", StackingClassifier(
                estimators=stack_estimators,
                final_estimator=LogisticRegression(max_iter=2000, random_state=SEED),
                stack_method="predict_proba",
                cv=5,
                n_jobs=-1,
            )),
        ]),
    ))

    return models

models = build_models(preprocessor)

print("Model count:", len(models))
for name, _ in models:
    print("-", name)
# Out:
# Model count: 10
# - LogisticRegression
# - DecisionTree_depth3
# - KNN_k15
# - GaussianNB
# - Bagging_depth3
# - RandomForest
# - AdaBoost_stumps
# - GradientBoosting_GBDT
# - XGBoost
# - Stacking_LR_RF_KNN

# %%
# Cross-validated comparison table (fair comparison across models)

rows = []
for name, estimator in models:
    t0 = time.time()

    cv_res = cross_validate(
        estimator,
        X_train,
        y_train,
        cv=cv,
        scoring=scoring,
        n_jobs=-1,
        return_train_score=False,
    )

    elapsed = time.time() - t0

    rows.append({
        "model": name,
        "f1_pos_mean": np.mean(cv_res["test_f1_pos"]),
        "f1_pos_std": np.std(cv_res["test_f1_pos"]),
        "avg_precision_mean": np.mean(cv_res["test_avg_precision"]),
        "avg_precision_std": np.std(cv_res["test_avg_precision"]),
        "roc_auc_mean": np.mean(cv_res["test_roc_auc"]),
        "roc_auc_std": np.std(cv_res["test_roc_auc"]),
        "cv_time_sec": elapsed,
    })

results_cv = pd.DataFrame(rows)
results_cv = results_cv.sort_values(by=["avg_precision_mean", "f1_pos_mean"], ascending=False).reset_index(drop=True)
display(results_cv)
# Out:
#                    model  f1_pos_mean  f1_pos_std  avg_precision_mean  \
# 0     LogisticRegression     0.658455    0.048473            0.742312
# 1     Stacking_LR_RF_KNN     0.645717    0.053560            0.731494
# 2                XGBoost     0.615260    0.034468            0.729110
# 3        AdaBoost_stumps     0.513383    0.071976            0.684274
# 4  GradientBoosting_GBDT     0.481301    0.058931            0.611052
# 5         Bagging_depth3     0.430789    0.016445            0.536945
# 6           RandomForest     0.007692    0.015385            0.426174
# 7    DecisionTree_depth3     0.407839    0.121945            0.387785
# 8                KNN_k15     0.030479    0.028319            0.291584
# 9             GaussianNB     0.207465    0.006664            0.109859
#
#    avg_precision_std  roc_auc_mean  roc_auc_std  cv_time_sec
# 0           0.031718      0.965252     0.004228     3.123788
# 1           0.040193      0.961304     0.005812    37.362676
# 2           0.036133      0.963199     0.006551     1.685327
# 3           0.030846      0.953700     0.006020     3.411267
# 4           0.059508      0.916765     0.020814     6.081634
# 5           0.056572      0.871876     0.064183     2.853639
# 6           0.084908      0.868254     0.017397     3.397715
# 7           0.084183      0.840356     0.050227     2.167204
# 8           0.049507      0.801333     0.026480     2.214250
# 9           0.004026      0.709029     0.010380     1.037243

# %% [markdown]
# ## 6) Hyperparameter Tuning (Chapter 15)
#
# We will tune the top-performing models using cross-validation on the training set only.
#
# Guiding principle from the textbook:
# - **Keep the test set untouched** until the end.
# - Use a consistent CV object + primary metric for tuning.
#
# Primary tuning metric for fraud here: **Average Precision** (PR AUC).

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform, randint

# Select top candidates from the CV comparison table
TOP_N = 3
candidates = results_cv.head(TOP_N)["model"].tolist()
print("Top candidates for tuning:")
print(candidates)

# Create a quick name -> estimator lookup
model_dict = {name: est for name, est in models}
# Out:
# Top candidates for tuning:
# ['LogisticRegression', 'Stacking_LR_RF_KNN', 'XGBoost']

# %%
# Define tuning search spaces for a few key model families
# We keep the search sizes modest to keep runtime reasonable in a notebook.

param_spaces = {}

# Logistic Regression
param_spaces["LogisticRegression"] = {
    "clf__C": loguniform(1e-3, 1e2),
    "clf__class_weight": [None, "balanced"],
}

# Random Forest
param_spaces["RandomForest"] = {
    "clf__n_estimators": randint(200, 900),
    "clf__max_depth": [None, 3, 5, 8, 12],
    "clf__min_samples_leaf": randint(1, 30),
    "clf__max_features": ["sqrt", "log2", None],
    "clf__class_weight": [None, "balanced"],
}

# Gradient Boosting (GBDT)
param_spaces["GradientBoosting_GBDT"] = {
    "clf__n_estimators": randint(100, 700),
    "clf__learning_rate": loguniform(1e-2, 2e-1),
    "clf__max_depth": randint(2, 6),
}

# AdaBoost
param_spaces["AdaBoost_stumps"] = {
    "clf__n_estimators": randint(50, 600),
    "clf__learning_rate": loguniform(1e-2, 1.0),
}

# Stacking meta-learner (logistic regression final estimator)
param_spaces["Stacking_LR_RF_KNN"] = {
    "clf__final_estimator__C": loguniform(1e-3, 10.0),
}

# XGBoost (only if available)
if HAS_XGBOOST:
    param_spaces["XGBoost"] = {
        "clf__n_estimators": randint(200, 900),
        "clf__learning_rate": loguniform(1e-2, 2e-1),
        "clf__max_depth": randint(2, 6),
        "clf__subsample": [0.6, 0.8, 1.0],
        "clf__colsample_bytree": [0.6, 0.8, 1.0],
        "clf__reg_lambda": loguniform(1e-2, 10.0),
    }

# Run RandomizedSearchCV for each candidate that has a defined space
primary_metric = "average_precision"

search_results = []
search_objects = {}

for name in candidates:
    if name not in param_spaces:
        print(f"Skipping tuning for {name}: no param space defined.")
        continue

    estimator = model_dict[name]
    space = param_spaces[name]

    search = RandomizedSearchCV(
        estimator=estimator,
        param_distributions=space,
        n_iter=25,
        scoring=primary_metric,
        cv=cv,
        n_jobs=-1,
        random_state=SEED,
        verbose=0,
        return_train_score=False,
    )

    t0 = time.time()
    search.fit(X_train, y_train)
    elapsed = time.time() - t0

    search_objects[name] = search

    search_results.append({
        "model": name,
        "best_score_avg_precision": float(search.best_score_),
        "best_params": search.best_params_,
        "search_time_sec": elapsed,
    })

results_tuned = pd.DataFrame(search_results).sort_values(by="best_score_avg_precision", ascending=False)
display(results_tuned)
# Out:
#                 model  best_score_avg_precision  \
# 0  LogisticRegression                  0.746059
# 2             XGBoost                  0.741149
# 1  Stacking_LR_RF_KNN                  0.731854
#
#                                          best_params  search_time_sec
# 0  {'clf__C': 0.3801673795564323, 'clf__class_wei...         3.558153
# 2  {'clf__colsample_bytree': 1.0, 'clf__learning_...        84.384030
# 1  {'clf__final_estimator__C': 0.050452842822425986}      1015.520606

# %% [markdown]
# ## 7) Feature selection + model selection round 2 (Chapter 16)
#
# Steps (leakage-safe):
#
# 1. Take the **round 1** best tuned pipeline and fit it on an inner training slice (`X_tr_pfi`).
# 2. Run **permutation importance** on the inner validation slice (`X_val_pfi`) — the frozen **test set is not used** to choose columns.
# 3. **Aggregate** importances to **raw** input columns; **drop** columns whose total contribution is **≤ 0**.
# 4. Rebuild the preprocessor + model zoo on the reduced `X_train`, re-run **cross-validation** and **RandomizedSearchCV**, and set **`best_model`** from this **round 2** result.
#
# _RFECV can be added as an optional diagnostic; the saved pipeline follows the PFI column set above._

# %%
# Round 1 winner (full feature set) — used to compute PFI for raw-column selection
if len(search_objects) > 0:
    best_tuned_name = results_tuned.iloc[0]["model"]
    best_model_r1 = search_objects[best_tuned_name].best_estimator_
    print("Round 1 best tuned model:", best_tuned_name)
else:
    best_tuned_name = results_cv.iloc[0]["model"]
    best_model_r1 = model_dict[best_tuned_name]
    print("No tuned models in round 1; best CV model:", best_tuned_name)

best_model_r1
# Out:
# Round 1 best tuned model: LogisticRegression
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['customer_id', 'promo_used',
#                                                    'order_subtotal',
#                                                    'shipping_fee', 'tax_amount',
#                                                    'order_total',
#                                                    'promised_days',
#                                                    'actual_days',
#                                                    'late_delivery',
#                                                    'n_line_items', 'n_units',
#                                                    'items_revenue',
#                                                    'avg_unit_price',
#                                                    'max_un...
#                                                    'shipping_zip',
#                                                    'shipping_state',
#                                                    'payment_method',
#                                                    'device_type', 'ip_country',
#                                                    'gender', 'birthdate',
#                                                    'customer_created_at',
#                                                    'customer_city',
#                                                    'customer_state',
#                                                    'customer_zip',
#                                                    'customer_segment',
#                                                    'loyalty_tier',
#                                                    'ship_datetime', 'carrier',
#                                                    'shipping_method',
#                                                    'distance_band'])])),
#                 ('clf',
#                  LogisticRegression(C=np.float64(0.3801673795564323),
#                                     max_iter=2000, random_state=27))])

# %%
# --- PFI on inner validation (select raw columns) ---
from collections import defaultdict
from sklearn.base import clone
from sklearn.inspection import permutation_importance


m_r1 = clone(best_model_r1)
m_r1.fit(X_tr_pfi, y_tr_pfi)

pfi_r1 = permutation_importance(
    m_r1,
    X_val_pfi,
    y_val_pfi,
    scoring="average_precision",
    n_repeats=10,
    random_state=SEED,
    n_jobs=-1,
)

# sklearn permutes *raw* columns of X: len(importances) == n_features in X, not one-hot width.
pfi_cols = list(X_val_pfi.columns)
if len(pfi_cols) != len(pfi_r1.importances_mean):
    raise ValueError(
        f"PFI length {len(pfi_r1.importances_mean)} vs X columns {len(pfi_cols)}"
    )

agg = defaultdict(float)
for i, col in enumerate(pfi_cols):
    agg[col] += max(0.0, float(pfi_r1.importances_mean[i]))

MIN_RAW_FEATURES = 5
selected_cols = [c for c in X_train.columns if agg.get(c, 0.0) > 0.0]
if len(selected_cols) < MIN_RAW_FEATURES:
    ranked = [c for c, _ in sorted(agg.items(), key=lambda x: -x[1])]
    selected_cols = ranked[: max(MIN_RAW_FEATURES, 1)]

print(f"PFI kept {len(selected_cols)} / {X_train.shape[1]} raw columns (inner validation, not test).")

X_train_fs = X_train[selected_cols].copy()
X_test_fs = X_test[selected_cols].copy()

preprocessor, cat_cols, num_cols = make_column_preprocessor(X_train_fs)
models = build_models(preprocessor)

# --- Round 2: cross-validate all models on reduced features ---
rows_fs = []
for name, estimator in models:
    t0 = time.time()
    cv_res = cross_validate(
        estimator,
        X_train_fs,
        y_train,
        cv=cv,
        scoring=scoring,
        n_jobs=-1,
        return_train_score=False,
    )
    elapsed = time.time() - t0
    rows_fs.append({
        "model": name,
        "f1_pos_mean": np.mean(cv_res["test_f1_pos"]),
        "f1_pos_std": np.std(cv_res["test_f1_pos"]),
        "avg_precision_mean": np.mean(cv_res["test_avg_precision"]),
        "avg_precision_std": np.std(cv_res["test_avg_precision"]),
        "roc_auc_mean": np.mean(cv_res["test_roc_auc"]),
        "roc_auc_std": np.std(cv_res["test_roc_auc"]),
        "cv_time_sec": elapsed,
    })

results_cv_fs = pd.DataFrame(rows_fs)
results_cv_fs = results_cv_fs.sort_values(
    by=["avg_precision_mean", "f1_pos_mean"], ascending=False
).reset_index(drop=True)
print("=== Round 2 (after PFI column selection): CV ===")
display(results_cv_fs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 40
#      36
#      37 agg = defaultdict(float)
#      38 for i, fname in enumerate(fn_out):
#      39     raw_c = _raw_col_from_ct_name(str(fname), num_cols_r1, cat_cols_r1)
# ---> 40     agg[raw_c] += max(0.0, float(pfi_r1.importances_mean[i]))
#      41
#      42 MIN_RAW_FEATURES = 5
#      43 selected_cols = [c for c in X_train.columns if agg.get(c, 0.0) > 0.0]
#
# IndexError: index 38 is out of bounds for axis 0 with size 38

# %%
# --- Round 2: hyperparameter search on top candidates ---
candidates_fs = results_cv_fs.head(TOP_N)["model"].tolist()
print("Round 2 tuning candidates:", candidates_fs)

model_dict_fs = {name: est for name, est in models}
search_results_fs = []
search_objects_fs = {}

for name in candidates_fs:
    if name not in param_spaces:
        print(f"Skipping round-2 tuning for {name}: no param space defined.")
        continue
    estimator = model_dict_fs[name]
    space = param_spaces[name]
    search2 = RandomizedSearchCV(
        estimator=estimator,
        param_distributions=space,
        n_iter=25,
        scoring="average_precision",
        cv=cv,
        n_jobs=-1,
        random_state=SEED,
        verbose=0,
        return_train_score=False,
    )
    t0 = time.time()
    search2.fit(X_train_fs, y_train)
    elapsed = time.time() - t0
    search_objects_fs[name] = search2
    search_results_fs.append({
        "model": name,
        "best_score_avg_precision": float(search2.best_score_),
        "best_params": search2.best_params_,
        "search_time_sec": elapsed,
    })

results_tuned_fs = pd.DataFrame(search_results_fs).sort_values(
    by="best_score_avg_precision", ascending=False
)
print("=== Round 2: RandomizedSearchCV ===")
display(results_tuned_fs)

if len(search_objects_fs) > 0:
    best_tuned_name_fs = results_tuned_fs.iloc[0]["model"]
    best_model = search_objects_fs[best_tuned_name_fs].best_estimator_
    print("Selected model (round 2 tuned):", best_tuned_name_fs)
else:
    best_tuned_name_fs = results_cv_fs.iloc[0]["model"]
    best_model = model_dict_fs[best_tuned_name_fs]
    print("Round 2: using best CV estimator:", best_tuned_name_fs)

# Training / test matrices for final fit and evaluation
X_train_final = X_train_fs
X_test_final = X_test_fs

# %% [markdown]
# ## 8) Final evaluation and model artifact
#
# We evaluate the **round 2** `best_model` (PFI-reduced columns + retuned) on the **frozen** holdout once.
#
# Metrics emphasize precision/recall behavior under imbalance:
# - Confusion matrix
# - Precision / recall / F1 for the fraud class (1)
# - Precision–Recall curve / Average Precision

# %%
from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report,
    f1_score,
    average_precision_score,
    precision_recall_curve,
)

# Round 2 winner: same preprocessing column set as X_train_final / X_test_final
final_model = best_model
final_model.fit(X_train_final, y_train)

y_pred = final_model.predict(X_test_final)

y_proba = None
if hasattr(final_model, "predict_proba"):
    y_proba = final_model.predict_proba(X_test_final)[:, 1]

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 4))
ConfusionMatrixDisplay(cm, display_labels=["not_fraud (0)", "fraud (1)"]).plot(values_format="d", cmap="Blues")
plt.title("Confusion Matrix (Frozen Test Set, Round 2 Model)")
plt.tight_layout()
plt.show()

print(classification_report(y_test, y_pred, digits=4, zero_division=0))

f1_pos = f1_score(y_test, y_pred, pos_label=1)
print("F1 (fraud=1):", round(float(f1_pos), 4))

if y_proba is not None:
    ap = average_precision_score(y_test, y_proba)
    print("Average Precision (PR AUC):", round(float(ap), 4))

    prec, rec, thr = precision_recall_curve(y_test, y_proba)
    plt.figure(figsize=(5, 4))
    plt.plot(rec, prec)
    plt.title("Precision-Recall Curve (Frozen Test Set)")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Model selection rationale (fraud context)
#
# In fraud detection, overall accuracy is often misleading because the non-fraud class dominates.
#
# We prioritize **recall** and **precision** on the fraud class, **F1**, and **PR AUC / Average Precision**.
#
# **Pipeline:** denormalize → clean → round 1 CV + tuning on full features → **PFI (validation-only)** drops unhelpful raw columns → **round 2** CV + tuning → final test evaluation → optional `joblib` artifact for scoring new rows built with the **same** reduced column list.

# %% [markdown]
# ### Serialize fitted model (`fraud_model_pipeline.sav`)
#
# The cell below saves the **fitted round 2 `Pipeline`** (preprocessing + classifier on the **PFI-selected columns**). Load with `joblib.load` and call `predict` / `predict_proba` on new rows that match **`X_train_final.columns`** (same SQL/feature construction, then drop to the same raw fields).

# %%
import joblib

# Save the fitted end-to-end pipeline so predictions use the same imputation, scaling,
# and one-hot encoding as training (avoids training-serving skew).
# `final_model` is the Pipeline from the "Final Evaluation" cell (preprocessor + classifier).

MODEL_SAV_PATH = os.path.join(PROJECT_ROOT, "fraud_model_pipeline.sav")
joblib.dump(final_model, MODEL_SAV_PATH)
print("Saved fitted pipeline to:", MODEL_SAV_PATH)
print(f"Load later with: model = joblib.load({MODEL_SAV_PATH!r})")

# %%
# Clean up the database connection
if conn is not None:
    conn.close()
print("Done.")
